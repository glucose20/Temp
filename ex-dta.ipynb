# %%
# %pip install -q numpy pandas scipy scikit-learn torch tqdm gensim matplotlib mol2vec fair-esm
# %pip install -q rdkit psutil
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.4 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 23.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 15.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 99.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 5.4 MB/s eta 0:00:00
# ...

# %%
import os
import pathlib
import subprocess

# !git clone --branch new-expert-trial https://github.com/glucose20/Temp.git
# Out:
# Cloning into 'Temp'...
# remote: Enumerating objects: 441, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 441 (delta 28), reused 45 (delta 21), pack-reused 387 (from 1)
# Receiving objects: 100% (441/441), 112.86 MiB | 46.14 MiB/s, done.
# Resolving deltas: 100% (203/203), done.

# %%
import os
import shutil

# Kaggle tự mount dataset tại /kaggle/input/<dataset-name>
base_dir = '/kaggle/input/llmdta/pretrain-feature/pretrained-feature'
destination_dir = '/kaggle/working/Temp/data'

# Tạo thư mục đích nếu chưa có
os.makedirs(destination_dir, exist_ok=True)

# Danh sách dataset cần copy
datasets = ['davis', 'kiba', 'metz']

for name in datasets:
    src = os.path.join(base_dir, name)
    dst = os.path.join(destination_dir, name)
    
    # Nếu thư mục đích đã tồn tại thì xóa để tránh lỗi copytree
    if os.path.exists(dst):
        shutil.rmtree(dst)
    
    shutil.copytree(src, dst)
    print(f"✅ Copied {name} → {destination_dir}")

print("\n🎯 All datasets copied successfully to /kaggle/working/data!")
# Out:
# ✅ Copied davis → /kaggle/working/Temp/data
# ✅ Copied kiba → /kaggle/working/Temp/data
# ✅ Copied metz → /kaggle/working/Temp/data
#
# 🎯 All datasets copied successfully to /kaggle/working/data!

# %%
# !tar -xzf /kaggle/working/Temp/data/dta-5fold-dataset/davis.tar.gz -C /kaggle/working/Temp/data/dta-5fold-dataset/
# !tar -xzf /kaggle/working/Temp/data/dta-5fold-dataset/kiba.tar.gz -C /kaggle/working/Temp/data/dta-5fold-dataset/
# !tar -xzf /kaggle/working/Temp/data/dta-5fold-dataset/metz.tar.gz -C /kaggle/working/Temp/data/dta-5fold-dataset/

# %%
# %cd /kaggle/working/Temp
# Out:
# /kaggle/working/Temp

# %%
# !python code/train_moe.py --fold 1 --cuda "1" --dataset davis --running_set warm \
  --epochs 200 --batch_size 16 --lr 1e-4 \
  --num_experts 4 --top_k 2 --lb_weight 0.005
# Out:
# ...
# Training LLMDTA with Mixture of Experts - davis/warm/fold0
# ...
# Device: cuda:0
# Loading dataset...
# Train size: 19236, Valid size: 4809, Test size: 6011
# /usr/local/lib/python3.11/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Model created with 4 experts, top-2 routing
# Load balancing weight: 0.005 (with 10 epochs warmup)
#
# Starting training...
# Epoch 1/1:   0%|                                       | 0/1203 [00:00<?, ?it/s]/kaggle/working/Temp/code/MyDataset.py:53: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   drug_id, prot_id, label = pair[-3], pair[-2], pair[-1]
# ...
